# %%
import pandas as pd

# %%
inflation = pd.read_excel("SeriesReport-20220623191557_2affe5.xlsx")
# Out:
# /Users/evanbruno/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
inflation
# Out:
#    CPI for All Urban Consumers (CPI-U)  \
# 0              12-Month Percent Change
# 1                                  NaN
# 2                           Series Id:
# 3              Not Seasonally Adjusted
# 4                        Series Title:
# 5                                Area:
# 6                                Item:
# 7                         Base Period:
# 8                               Years:
# 9                                  NaN
# 10                                Year
# 11                              2002.0
# 12                              2003.0
# 13                              2004.0
# 14                              2005.0
# 15                              2006.0
# 16                              2007.0
# 17                              2008.0
# 18                              2009.0
# 19                              2010.0
# 20                              2011.0
# 21                              2012.0
# 22                              2013.0
# ...
